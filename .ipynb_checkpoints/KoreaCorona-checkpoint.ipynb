# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import plotly.express as px
from datetime import date, timedelta
from sklearn.cluster import KMeans
from fbprophet import Prophet
from fbprophet.plot import plot_plotly, add_changepoints_to_plot
import plotly.offline as py
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from keras.models import Sequential
from keras.layers import LSTM,Dense
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# /Users/parkchanjin/PycharmProjects/ml-work/venv/lib/python3.7/site-packages/google/colab/data_table.py:30: UserWarning:
#
# IPython.utils.traitlets has moved to a top-level traitlets package.
#
# Using TensorFlow backend.

# %%
path = './Data/'
patient_data_path = path + 'patient.csv'
route_data_path = path + 'route.csv'
time_data_path = path + 'time.csv'
case_data_path = path + 'case.csv'

df_case = pd.read_csv(case_data_path)
df_patient = pd.read_csv(patient_data_path)
df_route = pd.read_csv(route_data_path)
df_time = pd.read_csv(time_data_path)

# %% [markdown]
# # 1. Chinese brought virus to Korea

# %%
df_patient.head()
# Out:
#    patient_id     sex  birth_year country               region  disease group  \
# 0           1  female      1984.0   China  filtered at airport      NaN   NaN
# 1           2    male      1964.0   Korea  filtered at airport      NaN   NaN
# 2           3    male      1966.0   Korea         capital area      NaN   NaN
# 3           4    male      1964.0   Korea         capital area      NaN   NaN
# 4           5    male      1987.0   Korea         capital area      NaN   NaN
#
#   infection_reason  infection_order  infected_by  contact_number  \
# 0   visit to Wuhan              1.0          NaN            45.0
# 1   visit to Wuhan              1.0          NaN            75.0
# 2   visit to Wuhan              1.0          NaN            16.0
# 3   visit to Wuhan              1.0          NaN            95.0
# 4   visit to Wuhan              1.0          NaN            31.0
#
#   confirmed_date released_date deceased_date     state
# 0     2020-01-20    2020-02-06           NaN  released
# 1     2020-01-24    2020-02-05           NaN  released
# 2     2020-01-26    2020-02-12           NaN  released
# 3     2020-01-27    2020-02-09           NaN  released
# 4     2020-01-30    2020-03-02           NaN  released

# %%
df_patient = df_patient.dropna(how='all')

# %%
df_patient.shape
# Out:
# (7869, 15)

# %% [markdown]
# # 1. Foreign income to Korea

# %%
df_patient['country'].value_counts()
# Out:
# Korea       7860
# China          8
# Mongolia       1
# Name: country, dtype: int64

# %% [markdown]
# # 1.1 China income to Korea

# %%
df_patient[df_patient['country'] == 'China'].shape
# Out:
# (8, 15)

# %%
china_income = df_patient[df_patient['country'] == 'China']

# %%
china_income = china_income.reset_index(drop=True)

# %%
china_income
# Out:
#    patient_id     sex  birth_year country               region  disease  \
# 0           1  female      1984.0   China  filtered at airport      NaN
# 1          12    male      1971.0   China         capital area      NaN
# 2          14  female      1980.0   China         capital area      NaN
# 3          23  female      1962.0   China         capital area      NaN
# 4          27  female      1982.0   China         capital area      NaN
# 5          28  female      1989.0   China         capital area      NaN
# 6         755    male      1954.0   China         capital area      NaN
# 7         924  female      1945.0   China         capital area      NaN
#
#                            group               infection_reason  \
# 0                            NaN                 visit to Wuhan
# 1                            NaN  contact with patient in Japan
# 2                            NaN           contact with patient
# 3                            NaN                 visit to Wuhan
# 4                            NaN                 visit to China
# 5                            NaN           contact with patient
# 6  Eunpyeong St. Mary's Hospital                            NaN
# 7                            NaN                 visit to China
#
#    infection_order  infected_by  contact_number confirmed_date released_date  \
# 0              1.0          NaN            45.0     2020-01-20    2020-02-06
# 1              2.0          NaN           422.0     2020-02-01    2020-02-18
# 2              3.0         12.0             3.0     2020-02-02    2020-02-18
# 3              1.0          NaN            23.0     2020-02-06    2020-02-29
# 4              1.0          NaN            40.0     2020-02-09           NaN
# 5              2.0          3.0             1.0     2020-02-10    2020-02-17
# 6              NaN          NaN             NaN     2020-02-24           NaN
# 7              NaN          NaN             NaN     2020-02-25           NaN
#
#   deceased_date     state
# 0           NaN  released
# 1           NaN  released
# 2           NaN  released
# 3           NaN  released
# 4           NaN  isolated
# 5           NaN  released
# 6           NaN  isolated
# 7           NaN  isolated

# %%
infectedby = df_patient[df_patient['infected_by'].notna()]

# %%
infectedby = infectedby.reset_index(drop=True)

# %% [markdown]
# # patients infected by income Chinese

# %% [markdown]
# # 8 -> 3

# %%
infectedbyList = infectedby['infected_by'].isin(china_income['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyChinese = pd.DataFrame(infectedby, index=infectedbyList)

# %%
infectedbyChinese
# Out:
#     patient_id     sex  birth_year country        region  disease group  \
# 4           14  female      1980.0   China  capital area      NaN   NaN
# 10          25  female      1946.0   Korea  capital area      NaN   NaN
# 11          26    male      1968.0   Korea  capital area      NaN   NaN
#
#         infection_reason  infection_order  infected_by  contact_number  \
# 4   contact with patient              3.0         12.0             3.0
# 10  contact with patient              2.0         27.0            12.0
# 11  contact with patient              1.0         27.0             0.0
#
#    confirmed_date released_date deceased_date     state
# 4      2020-02-02    2020-02-18           NaN  released
# 10     2020-02-09    2020-03-05           NaN  released
# 11     2020-02-09           NaN           NaN  isolated

# %%
infectedbyList2 = infectedby['infected_by'].isin(infectedbyChinese['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyList2
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# # No patients infected by patients infected by income Chinese
# # The most chinese patients are released state.

# %% [markdown]
# # = How systematic and good the Korean prevention of epidemics

# %% [markdown]
# # 1.2 Mongolia income to Korea

# %%
mongolia_income = df_patient[df_patient['country'] == 'Mongolia']

# %%
mongolia_income
# Out:
#      patient_id   sex  birth_year   country        region  disease group  \
# 874         875  male      1984.0  Mongolia  capital area      1.0   NaN
#
#     infection_reason  infection_order  infected_by  contact_number  \
# 874              NaN              NaN          NaN             NaN
#
#     confirmed_date released_date deceased_date     state
# 874     2020-02-25           NaN    2020-02-25  deceased

# %%
infectedbyList = infectedby['infected_by'].isin(mongolia_income['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyList
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# # No patients infected by Mongolia patients

# %% [markdown]
# # = No big group infection or spread from foreign patients(China, Mongolia)

# %% [markdown]
# # 2. Koreans income from abroad to Korea

# %%
koreanPatient = df_patient[df_patient['country'] == 'Korea']

# %%
koreanPatient['infection_reason'].value_counts()
# Out:
# contact with patient                 74
# visit to Daegu                       50
# visit to Wuhan                        6
# pilgrimage to Israel                  6
# contact with patient in Singapore     2
# residence in Wuhan                    2
# visit to Thailand                     2
# visit to Italy                        1
# visit to Vietnam                      1
# visit to ooo                          1
# visit to Japan                        1
# contact with patient in Daegu         1
# Name: infection_reason, dtype: int64

# %%
foreignVisit = ['visit to Wuhan', 'pilgrimage to Israel', 'visit to Thailand', 'residence in Wuhan', 'contact with patient in Singapore', 'visit to Italy', 'visit to Japan', 'visit to Vietnam', 'visit to ooo']

# %%
korea_income = koreanPatient.loc[koreanPatient['infection_reason'].isin(foreignVisit)]

# %%
korea_income['patient_id'].shape
# Out:
# (22,)

# %%
korea_income
# Out:
#       patient_id     sex  birth_year country               region  disease  \
# 1              2    male      1964.0   Korea  filtered at airport      NaN
# 2              3    male      1966.0   Korea         capital area      NaN
# 3              4    male      1964.0   Korea         capital area      NaN
# 4              5    male      1987.0   Korea         capital area      NaN
# 6              7    male      1991.0   Korea         capital area      NaN
# 7              8  female      1957.0   Korea         Jeollabuk-do      NaN
# 12            13    male      1992.0   Korea  filtered at airport      NaN
# 15            16  female      1977.0   Korea              Gwangju      NaN
# 16            17    male      1982.0   Korea         capital area      NaN
# 18            19    male      1983.0   Korea         capital area      NaN
# 23            24    male      1992.0   Korea  filtered at airport      NaN
# 347          348    male      1980.0   Korea         capital area      NaN
# 384          385    male      1956.0   Korea     Gyeongsangbuk-do      NaN
# 385          386    male      1956.0   Korea     Gyeongsangbuk-do      NaN
# 386          387  female      1960.0   Korea     Gyeongsangbuk-do      NaN
# 387          388  female      1960.0   Korea     Gyeongsangbuk-do      NaN
# 439          440  female      1957.0   Korea     Gyeongsangbuk-do      NaN
# 592          593    male      1968.0   Korea         capital area      NaN
# 1377        1378    male      1984.0   Korea         capital area      NaN
# 3516        3517    male      1951.0   Korea         capital area      NaN
# 3683        3684  female      1988.0   Korea         capital area      NaN
# 4344        4345  female      1972.0   Korea              Jeju-do      NaN
#
#            group                   infection_reason  infection_order  \
# 1            NaN                     visit to Wuhan              1.0
# 2            NaN                     visit to Wuhan              1.0
# 3            NaN                     visit to Wuhan              1.0
# 4            NaN                     visit to Wuhan              1.0
# 6            NaN                     visit to Wuhan              1.0
# 7            NaN                     visit to Wuhan              1.0
# 12           NaN                 residence in Wuhan              1.0
# 15           NaN                  visit to Thailand              1.0
# 16           NaN  contact with patient in Singapore              2.0
# 18           NaN  contact with patient in Singapore              2.0
# 23           NaN                 residence in Wuhan              1.0
# 347   Pilgrimage               pilgrimage to Israel              NaN
# 384   Pilgrimage               pilgrimage to Israel              NaN
# 385   Pilgrimage               pilgrimage to Israel              NaN
# 386   Pilgrimage               pilgrimage to Israel              NaN
# 387   Pilgrimage               pilgrimage to Israel              NaN
# 439   Pilgrimage               pilgrimage to Israel              NaN
# 592          NaN                   visit to Vietnam              NaN
# 1377         NaN                  visit to Thailand              NaN
# 3516         NaN                     visit to Japan              NaN
# 3683         NaN                     visit to Italy              NaN
# 4344         NaN                       visit to ooo              NaN
#
#       infected_by  contact_number confirmed_date released_date deceased_date  \
# 1             NaN            75.0     2020-01-24    2020-02-05           NaN
# 2             NaN            16.0     2020-01-26    2020-02-12           NaN
# 3             NaN            95.0     2020-01-27    2020-02-09           NaN
# 4             NaN            31.0     2020-01-30    2020-03-02           NaN
# 6             NaN             9.0     2020-01-30    2020-02-15           NaN
# 7             NaN           113.0     2020-01-31    2020-02-12           NaN
# 12            NaN             0.0     2020-02-02    2020-02-24           NaN
# 15            NaN           450.0     2020-02-04    2020-02-19           NaN
# 16            NaN           290.0     2020-02-05    2020-02-12           NaN
# 18            NaN            68.0     2020-02-05    2020-02-21           NaN
# 23            NaN             0.0     2020-02-06    2020-02-27           NaN
# 347           NaN             NaN     2020-02-22           NaN           NaN
# 384           NaN             NaN     2020-02-22           NaN           NaN
# 385           NaN             NaN     2020-02-22           NaN           NaN
# 386           NaN             NaN     2020-02-22           NaN           NaN
# 387           NaN             NaN     2020-02-22           NaN           NaN
# 439           NaN             NaN     2020-02-23           NaN           NaN
# 592           NaN             NaN     2020-02-23    2020-03-04           NaN
# 1377          NaN             NaN     2020-02-27    2020-03-03           NaN
# 3516          NaN             NaN     2020-03-01           NaN           NaN
# 3683          NaN             NaN     2020-03-01           NaN           NaN
# 4344          NaN            21.0     2020-03-02           NaN           NaN
#
#          state
# 1     released
# 2     released
# 3     released
# 4     released
# 6     released
# 7     released
# 12    released
# 15    released
# 16    released
# 18    released
# 23    released
# 347   isolated
# 384   isolated
# 385   isolated
# 386   isolated
# 387   isolated
# 439   isolated
# 592   released
# 1377  released
# 3516  isolated
# 3683  isolated
# 4344  isolated

# %%
infectedbyList = infectedby['infected_by'].isin(korea_income['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyKorean = pd.DataFrame(infectedby, index=infectedbyList)

# %%
infectedbyKorean
# Out:
#     patient_id     sex  birth_year country        region  disease group  \
# 0            6    male      1964.0   Korea  capital area      NaN   NaN
# 1            9  female      1992.0   Korea  capital area      NaN   NaN
# 5           15    male      1977.0   Korea  capital area      NaN   NaN
# 6           18  female      1999.0   Korea       Gwangju      NaN   NaN
# 9           22    male      1973.0   Korea       Gwangju      NaN   NaN
# 12          28  female      1989.0   China  capital area      NaN   NaN
#
#         infection_reason  infection_order  infected_by  contact_number  \
# 0   contact with patient              2.0          3.0            17.0
# 1   contact with patient              2.0          5.0             2.0
# 5   contact with patient              2.0          4.0            15.0
# 6   contact with patient              2.0         16.0             8.0
# 9   contact with patient              2.0         16.0             1.0
# 12  contact with patient              2.0          3.0             1.0
#
#    confirmed_date released_date deceased_date     state
# 0      2020-01-30    2020-02-19           NaN  released
# 1      2020-01-31    2020-02-24           NaN  released
# 5      2020-02-02    2020-02-24           NaN  released
# 6      2020-02-05    2020-02-19           NaN  released
# 9      2020-02-06    2020-02-15           NaN  released
# 12     2020-02-10    2020-02-17           NaN  released

# %% [markdown]
# # 22->6

# %%
infectedbyList2 = infectedby['infected_by'].isin(infectedbyKorean['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyKorean2 = pd.DataFrame(infectedby, index=infectedbyList2)

# %%
infectedbyKorean2
# Out:
#     patient_id     sex  birth_year country        region  disease group  \
# 2           10  female      1966.0   Korea  capital area      NaN   NaN
# 3           11    male      1995.0   Korea  capital area      NaN   NaN
# 7           20  female      1978.0   Korea  capital area      NaN   NaN
# 8           21  female      1960.0   Korea  capital area      NaN   NaN
# 23          83    male      1944.0   Korea  capital area      NaN   NaN
# 54        1252  female      1980.0   Korea       Daejeon      NaN   NaN
# 56        1257  female      1981.0   Korea       Daejeon      NaN   NaN
#
#         infection_reason  infection_order  infected_by  contact_number  \
# 2   contact with patient              3.0          6.0            43.0
# 3   contact with patient              3.0          6.0             0.0
# 7   contact with patient              3.0         15.0             2.0
# 8   contact with patient              3.0          6.0             6.0
# 23  contact with patient              3.0          6.0             NaN
# 54                   NaN              NaN         15.0             NaN
# 56        visit to Daegu              NaN          6.0             NaN
#
#    confirmed_date released_date deceased_date     state
# 2      2020-01-31    2020-02-19           NaN  released
# 3      2020-01-31    2020-02-10           NaN  released
# 7      2020-02-05    2020-02-24           NaN  released
# 8      2020-02-05    2020-02-29           NaN  released
# 23     2020-02-20    2020-03-01           NaN  released
# 54     2020-02-26           NaN           NaN  isolated
# 56     2020-02-26           NaN           NaN  isolated

# %% [markdown]
# # 22->6->7

# %%
infectedbyList3 = infectedby['infected_by'].isin(infectedbyKorean2['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyKorean3 = pd.DataFrame(infectedby, index=infectedbyList3)
infectedbyKorean3
# Out:
#     patient_id     sex  birth_year country        region  disease group  \
# 13          29    male      1938.0   Korea  capital area      NaN   NaN
# 15          32  female      2009.0   Korea  capital area      NaN   NaN
# 22          56    male      1945.0   Korea  capital area      NaN   NaN
# 59        1568    male      1985.0   Korea       Daejeon      NaN   NaN
# 63        1856    male      1985.0   Korea       Daejeon      NaN   NaN
# 65        1913    male      1975.0   Korea       Daejeon      NaN   NaN
#
#         infection_reason  infection_order  infected_by  contact_number  \
# 13  contact with patient              4.0         83.0           117.0
# 15  contact with patient              NaN         20.0             NaN
# 22  contact with patient              4.0         83.0             NaN
# 59  contact with patient              NaN       1252.0             2.0
# 63  contact with patient              NaN       1252.0             2.0
# 65  contact with patient              NaN       1257.0            61.0
#
#    confirmed_date released_date deceased_date     state
# 13     2020-02-16           NaN           NaN  isolated
# 15     2020-02-18    2020-03-04           NaN  released
# 22     2020-02-19           NaN           NaN  isolated
# 59     2020-02-27           NaN           NaN  isolated
# 63     2020-02-28           NaN           NaN  isolated
# 65     2020-02-28           NaN           NaN  isolated

# %% [markdown]
# # 22->6->7->6

# %%
infectedbyList4 = infectedby['infected_by'].isin(infectedbyKorean3['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyKorean4 = pd.DataFrame(infectedby, index=infectedbyList4)
infectedbyKorean4
# Out:
#     patient_id     sex  birth_year country        region  disease group  \
# 14          30  female      1952.0   Korea  capital area      NaN   NaN
# 26         136    male      1936.0   Korea  capital area      NaN   NaN
#
#         infection_reason  infection_order  infected_by  contact_number  \
# 14  contact with patient              5.0         29.0            27.0
# 26  contact with patient              5.0         56.0             NaN
#
#    confirmed_date released_date deceased_date     state
# 14     2020-02-16           NaN           NaN  isolated
# 26     2020-02-21           NaN           NaN  isolated

# %% [markdown]
# # 22->6->7->6->2

# %%
infectedbyList5 = infectedby['infected_by'].isin(infectedbyKorean4['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyKorean5 = pd.DataFrame(infectedby, index=infectedbyList5)
infectedbyKorean5
# Out:
#     patient_id     sex  birth_year country        region  disease group  \
# 24         112  female      1941.0   Korea  capital area      NaN   NaN
# 33         362    male      1956.0   Korea  capital area      NaN   NaN
#
#         infection_reason  infection_order  infected_by  contact_number  \
# 24  contact with patient              5.0        136.0             NaN
# 33  contact with patient              6.0         30.0             NaN
#
#    confirmed_date released_date deceased_date     state
# 24     2020-02-21           NaN           NaN  isolated
# 33     2020-02-22           NaN           NaN  isolated

# %% [markdown]
# # 22->6->7->6->2->2

# %%
infectedbyList6 = infectedby['infected_by'].isin(infectedbyKorean5['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyKorean6 = pd.DataFrame(infectedby, index=infectedbyList6)
infectedbyKorean6
# Out:
# Empty DataFrame
# Columns: [patient_id, sex, birth_year, country, region, disease, group, infection_reason, infection_order, infected_by, contact_number, confirmed_date, released_date, deceased_date, state]
# Index: []

# %%
frames = [korea_income, infectedbyKorean, infectedbyKorean2, infectedbyKorean3, infectedbyKorean4, infectedbyKorean5]

# %%
korea_income = pd.concat(frames)

# %%
korea_income.shape
# Out:
# (45, 15)

# %%
korea_income.reset_index(drop=True)
# Out:
#     patient_id     sex  birth_year country               region  disease  \
# 0            2    male      1964.0   Korea  filtered at airport      NaN
# 1            3    male      1966.0   Korea         capital area      NaN
# 2            4    male      1964.0   Korea         capital area      NaN
# 3            5    male      1987.0   Korea         capital area      NaN
# 4            7    male      1991.0   Korea         capital area      NaN
# 5            8  female      1957.0   Korea         Jeollabuk-do      NaN
# 6           13    male      1992.0   Korea  filtered at airport      NaN
# 7           16  female      1977.0   Korea              Gwangju      NaN
# 8           17    male      1982.0   Korea         capital area      NaN
# 9           19    male      1983.0   Korea         capital area      NaN
# 10          24    male      1992.0   Korea  filtered at airport      NaN
# 11         348    male      1980.0   Korea         capital area      NaN
# 12         385    male      1956.0   Korea     Gyeongsangbuk-do      NaN
# 13         386    male      1956.0   Korea     Gyeongsangbuk-do      NaN
# 14         387  female      1960.0   Korea     Gyeongsangbuk-do      NaN
# 15         388  female      1960.0   Korea     Gyeongsangbuk-do      NaN
# 16         440  female      1957.0   Korea     Gyeongsangbuk-do      NaN
# 17         593    male      1968.0   Korea         capital area      NaN
# 18        1378    male      1984.0   Korea         capital area      NaN
# 19        3517    male      1951.0   Korea         capital area      NaN
# 20        3684  female      1988.0   Korea         capital area      NaN
# 21        4345  female      1972.0   Korea              Jeju-do      NaN
# 22           6    male      1964.0   Korea         capital area      NaN
# 23           9  female      1992.0   Korea         capital area      NaN
# 24          15    male      1977.0   Korea         capital area      NaN
# 25          18  female      1999.0   Korea              Gwangju      NaN
# 26          22    male      1973.0   Korea              Gwangju      NaN
# 27          28  female      1989.0   China         capital area      NaN
# 28          10  female      1966.0   Korea         capital area      NaN
# 29          11    male      1995.0   Korea         capital area      NaN
# 30          20  female      1978.0   Korea         capital area      NaN
# 31          21  female      1960.0   Korea         capital area      NaN
# 32          83    male      1944.0   Korea         capital area      NaN
# 33        1252  female      1980.0   Korea              Daejeon      NaN
# 34        1257  female      1981.0   Korea              Daejeon      NaN
# 35          29    male      1938.0   Korea         capital area      NaN
# 36          32  female      2009.0   Korea         capital area      NaN
# 37          56    male      1945.0   Korea         capital area      NaN
# 38        1568    male      1985.0   Korea              Daejeon      NaN
# 39        1856    male      1985.0   Korea              Daejeon      NaN
# 40        1913    male      1975.0   Korea              Daejeon      NaN
# 41          30  female      1952.0   Korea         capital area      NaN
# 42         136    male      1936.0   Korea         capital area      NaN
# 43         112  female      1941.0   Korea         capital area      NaN
# 44         362    male      1956.0   Korea         capital area      NaN
#
#          group                   infection_reason  infection_order  \
# 0          NaN                     visit to Wuhan              1.0
# 1          NaN                     visit to Wuhan              1.0
# 2          NaN                     visit to Wuhan              1.0
# 3          NaN                     visit to Wuhan              1.0
# 4          NaN                     visit to Wuhan              1.0
# 5          NaN                     visit to Wuhan              1.0
# 6          NaN                 residence in Wuhan              1.0
# 7          NaN                  visit to Thailand              1.0
# 8          NaN  contact with patient in Singapore              2.0
# 9          NaN  contact with patient in Singapore              2.0
# 10         NaN                 residence in Wuhan              1.0
# 11  Pilgrimage               pilgrimage to Israel              NaN
# 12  Pilgrimage               pilgrimage to Israel              NaN
# 13  Pilgrimage               pilgrimage to Israel              NaN
# 14  Pilgrimage               pilgrimage to Israel              NaN
# 15  Pilgrimage               pilgrimage to Israel              NaN
# 16  Pilgrimage               pilgrimage to Israel              NaN
# 17         NaN                   visit to Vietnam              NaN
# 18         NaN                  visit to Thailand              NaN
# 19         NaN                     visit to Japan              NaN
# 20         NaN                     visit to Italy              NaN
# 21         NaN                       visit to ooo              NaN
# 22         NaN               contact with patient              2.0
# 23         NaN               contact with patient              2.0
# 24         NaN               contact with patient              2.0
# 25         NaN               contact with patient              2.0
# 26         NaN               contact with patient              2.0
# 27         NaN               contact with patient              2.0
# 28         NaN               contact with patient              3.0
# 29         NaN               contact with patient              3.0
# 30         NaN               contact with patient              3.0
# 31         NaN               contact with patient              3.0
# 32         NaN               contact with patient              3.0
# 33         NaN                                NaN              NaN
# 34         NaN                     visit to Daegu              NaN
# 35         NaN               contact with patient              4.0
# 36         NaN               contact with patient              NaN
# 37         NaN               contact with patient              4.0
# 38         NaN               contact with patient              NaN
# 39         NaN               contact with patient              NaN
# 40         NaN               contact with patient              NaN
# 41         NaN               contact with patient              5.0
# 42         NaN               contact with patient              5.0
# 43         NaN               contact with patient              5.0
# 44         NaN               contact with patient              6.0
#
#     infected_by  contact_number confirmed_date released_date deceased_date  \
# 0           NaN            75.0     2020-01-24    2020-02-05           NaN
# 1           NaN            16.0     2020-01-26    2020-02-12           NaN
# 2           NaN            95.0     2020-01-27    2020-02-09           NaN
# 3           NaN            31.0     2020-01-30    2020-03-02           NaN
# 4           NaN             9.0     2020-01-30    2020-02-15           NaN
# 5           NaN           113.0     2020-01-31    2020-02-12           NaN
# 6           NaN             0.0     2020-02-02    2020-02-24           NaN
# 7           NaN           450.0     2020-02-04    2020-02-19           NaN
# 8           NaN           290.0     2020-02-05    2020-02-12           NaN
# 9           NaN            68.0     2020-02-05    2020-02-21           NaN
# 10          NaN             0.0     2020-02-06    2020-02-27           NaN
# 11          NaN             NaN     2020-02-22           NaN           NaN
# 12          NaN             NaN     2020-02-22           NaN           NaN
# 13          NaN             NaN     2020-02-22           NaN           NaN
# 14          NaN             NaN     2020-02-22           NaN           NaN
# 15          NaN             NaN     2020-02-22           NaN           NaN
# 16          NaN             NaN     2020-02-23           NaN           NaN
# 17          NaN             NaN     2020-02-23    2020-03-04           NaN
# 18          NaN             NaN     2020-02-27    2020-03-03           NaN
# 19          NaN             NaN     2020-03-01           NaN           NaN
# 20          NaN             NaN     2020-03-01           NaN           NaN
# 21          NaN            21.0     2020-03-02           NaN           NaN
# 22          3.0            17.0     2020-01-30    2020-02-19           NaN
# 23          5.0             2.0     2020-01-31    2020-02-24           NaN
# 24          4.0            15.0     2020-02-02    2020-02-24           NaN
# 25         16.0             8.0     2020-02-05    2020-02-19           NaN
# 26         16.0             1.0     2020-02-06    2020-02-15           NaN
# 27          3.0             1.0     2020-02-10    2020-02-17           NaN
# 28          6.0            43.0     2020-01-31    2020-02-19           NaN
# 29          6.0             0.0     2020-01-31    2020-02-10           NaN
# 30         15.0             2.0     2020-02-05    2020-02-24           NaN
# 31          6.0             6.0     2020-02-05    2020-02-29           NaN
# 32          6.0             NaN     2020-02-20    2020-03-01           NaN
# 33         15.0             NaN     2020-02-26           NaN           NaN
# 34          6.0             NaN     2020-02-26           NaN           NaN
# 35         83.0           117.0     2020-02-16           NaN           NaN
# 36         20.0             NaN     2020-02-18    2020-03-04           NaN
# 37         83.0             NaN     2020-02-19           NaN           NaN
# 38       1252.0             2.0     2020-02-27           NaN           NaN
# 39       1252.0             2.0     2020-02-28           NaN           NaN
# 40       1257.0            61.0     2020-02-28           NaN           NaN
# 41         29.0            27.0     2020-02-16           NaN           NaN
# 42         56.0             NaN     2020-02-21           NaN           NaN
# 43        136.0             NaN     2020-02-21           NaN           NaN
# 44         30.0             NaN     2020-02-22           NaN           NaN
#
#        state
# 0   released
# 1   released
# 2   released
# 3   released
# 4   released
# 5   released
# 6   released
# 7   released
# 8   released
# 9   released
# 10  released
# 11  isolated
# 12  isolated
# 13  isolated
# 14  isolated
# 15  isolated
# 16  isolated
# 17  released
# 18  released
# 19  isolated
# 20  isolated
# 21  isolated
# 22  released
# 23  released
# 24  released
# 25  released
# 26  released
# 27  released
# 28  released
# 29  released
# 30  released
# 31  released
# 32  released
# 33  isolated
# 34  isolated
# 35  isolated
# 36  released
# 37  isolated
# 38  isolated
# 39  isolated
# 40  isolated
# 41  isolated
# 42  isolated
# 43  isolated
# 44  isolated

# %% [markdown]
# # 22+6+7+6+2+2 = 45
# # Total 45 patients are infected by Koreans income frome abroad
# # assuming that more patients might be infected by Koreans income

# %% [markdown]
# # 3. Shincheonji church group infection

# %% [markdown]
# 신천지 환자들로부터 infected by 출력해보고,
#
# 신천지 contact_number가 많은 환자들 region
# df_patient daugu
#
# df_patient infection_reason이 visit to daugu 출력

# %%
df_SCJChurch = df_patient[df_patient['group'] == 'Shincheonji Church']

# %%
df_SCJChurch.shape
# Out:
# (58, 15)

# %%
df_SCJChurch.head()
# Out:
#     patient_id     sex  birth_year country            region  disease  \
# 30          31  female      1959.0   Korea             Daegu      NaN
# 33          34    male      1996.0   Korea             Daegu      NaN
# 34          35  female      1994.0   Korea             Daegu      NaN
# 35          36  female      1972.0   Korea             Daegu      NaN
# 38          39  female      1959.0   Korea  Gyeongsangbuk-do      NaN
#
#                  group infection_reason  infection_order  infected_by  \
# 30  Shincheonji Church              NaN              NaN          NaN
# 33  Shincheonji Church              NaN              NaN          NaN
# 34  Shincheonji Church              NaN              NaN          NaN
# 35  Shincheonji Church              NaN              NaN          NaN
# 38  Shincheonji Church              NaN              NaN          NaN
#
#     contact_number confirmed_date released_date deceased_date     state
# 30          1160.0     2020-02-18           NaN           NaN  isolated
# 33             NaN     2020-02-18           NaN           NaN  isolated
# 34             NaN     2020-02-18           NaN           NaN  isolated
# 35             NaN     2020-02-18           NaN           NaN  isolated
# 38            31.0     2020-02-18    2020-03-03           NaN  released

# %%
infectedbyChurchList = infectedby['infected_by'].isin(df_SCJChurch['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyChurch = pd.DataFrame(infectedby, index=infectedbyChurchList)

# %%
infectedbyChurch.shape
# Out:
# (18, 15)

# %% [markdown]
# # 58->18

# %%
infectedbyChurch
# Out:
#     patient_id     sex  birth_year country        region  disease  \
# 16          33  female      1980.0   Korea         Daegu      NaN
# 17          47  female      1957.0   Korea         Daegu      NaN
# 18          48  female      1948.0   Korea         Daegu      NaN
# 19          49    male      1962.0   Korea         Daegu      NaN
# 20          50    male      1944.0   Korea         Daegu      NaN
# 21          51  female      1959.0   Korea         Daegu      NaN
# 27         140  female      1988.0   Korea         Daegu      NaN
# 28         162    male      1987.0   Korea         Daegu      NaN
# 29         164    male      1989.0   Korea       Gwangju      NaN
# 35         441  female      1959.0   Korea  capital area      NaN
# 37         489    male      1985.0   Korea       Gwangju      NaN
# 38         565    male      1980.0   Korea  capital area      NaN
# 40         589  female      1985.0   Korea       Gwangju      NaN
# 41         611    male      1985.0   Korea       Gwangju      NaN
# 46         835    male      1986.0   Korea  capital area      NaN
# 50        1227    male      1981.0   Korea  capital area      NaN
# 55        1256  female      1987.0   Korea       Daejeon      NaN
# 66        2468  female      1985.0   Korea  capital area      NaN
#
#                  group      infection_reason  infection_order  infected_by  \
# 16                 NaN  contact with patient              NaN         31.0
# 17  Shincheonji Church  contact with patient              NaN         31.0
# 18  Shincheonji Church  contact with patient              NaN         31.0
# 19  Shincheonji Church  contact with patient              NaN         31.0
# 20  Shincheonji Church  contact with patient              NaN         31.0
# 21  Shincheonji Church  contact with patient              NaN         31.0
# 27                 NaN  contact with patient              NaN         31.0
# 28                 NaN  contact with patient              NaN         31.0
# 29  Shincheonji Church  contact with patient              NaN        126.0
# 35                 NaN  contact with patient              NaN        246.0
# 37                 NaN  contact with patient              NaN        126.0
# 38                 NaN  contact with patient              NaN        246.0
# 40                 NaN  contact with patient              NaN        126.0
# 41                 NaN  contact with patient              NaN        164.0
# 46  Shincheonji Church  contact with patient              NaN        188.0
# 50                 NaN  contact with patient              NaN        835.0
# 55                 NaN                   NaN              NaN         44.0
# 66                 NaN  contact with patient              NaN       1247.0
#
#     contact_number confirmed_date released_date deceased_date     state
# 16             NaN     2020-02-18           NaN           NaN  isolated
# 17             NaN     2020-02-19           NaN           NaN  isolated
# 18             NaN     2020-02-19           NaN           NaN  isolated
# 19             NaN     2020-02-19           NaN           NaN  isolated
# 20             NaN     2020-02-19    2020-03-02           NaN  released
# 21             NaN     2020-02-19    2020-02-26           NaN  released
# 27             NaN     2020-02-21           NaN           NaN  isolated
# 28             NaN     2020-02-21           NaN           NaN  isolated
# 29             NaN     2020-02-21           NaN           NaN  isolated
# 35             NaN     2020-02-23           NaN           NaN  isolated
# 37            39.0     2020-02-23           NaN           NaN  isolated
# 38             NaN     2020-02-23           NaN           NaN  isolated
# 40            47.0     2020-02-23    2020-02-27           NaN  released
# 41             NaN     2020-02-24           NaN           NaN  isolated
# 46             NaN     2020-02-25           NaN           NaN  isolated
# 50             NaN     2020-02-26           NaN           NaN  isolated
# 55             NaN     2020-02-26    2020-03-02           NaN  released
# 66             NaN     2020-02-29    2020-03-04           NaN  released

# %%
infectedbyChurchList2 = infectedby['infected_by'].isin(infectedbyChurch['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyChurch2 = pd.DataFrame(infectedby, index=infectedbyChurchList2)

# %% [markdown]
# # 55->18->2

# %%
infectedbyChurch2.shape
# Out:
# (2, 15)

# %%
infectedbyChurch2
# Out:
#     patient_id   sex  birth_year country        region  disease group  \
# 41         611  male      1985.0   Korea       Gwangju      NaN   NaN
# 50        1227  male      1981.0   Korea  capital area      NaN   NaN
#
#         infection_reason  infection_order  infected_by  contact_number  \
# 41  contact with patient              NaN        164.0             NaN
# 50  contact with patient              NaN        835.0             NaN
#
#    confirmed_date released_date deceased_date     state
# 41     2020-02-24           NaN           NaN  isolated
# 50     2020-02-26           NaN           NaN  isolated

# %%
infectedbyChurchList3 = infectedby['infected_by'].isin(infectedbyChurch2['patient_id']).replace({False:np.nan}).dropna().index

# %%
infectedbyChurch3 = pd.DataFrame(infectedby, index=infectedbyChurchList3)

# %%
infectedbyChurch3.shape
# Out:
# (0, 15)

# %% [markdown]
# # 58+18+2 = total 78 patients are infected from SCJ Church.

# %%
frames = [df_SCJChurch, infectedbyChurch, infectedbyChurch2]

# %%
SCJChurch_infect = pd.concat(frames)

# %%
SCJChurch_infect.shape
# Out:
# (78, 15)

# %%
SCJChurch_infect
# Out:
#       patient_id     sex  birth_year country            region  disease  \
# 30            31  female      1959.0   Korea             Daegu      NaN
# 33            34    male      1996.0   Korea             Daegu      NaN
# 34            35  female      1994.0   Korea             Daegu      NaN
# 35            36  female      1972.0   Korea             Daegu      NaN
# 38            39  female      1959.0   Korea  Gyeongsangbuk-do      NaN
# 40            41  female      1951.0   Korea  Gyeongsangbuk-do      NaN
# 41            42  female      1991.0   Korea             Daegu      NaN
# 42            43  female      1962.0   Korea             Daegu      NaN
# 43            44  female      1974.0   Korea             Daegu      NaN
# 46            47  female      1957.0   Korea             Daegu      NaN
# 47            48  female      1948.0   Korea             Daegu      NaN
# 48            49    male      1962.0   Korea             Daegu      NaN
# 49            50    male      1944.0   Korea             Daegu      NaN
# 50            51  female      1959.0   Korea             Daegu      NaN
# 65            66    male      1998.0   Korea  Gyeongsangbuk-do      NaN
# 84            85  female      1972.0   Korea  Gyeongsangbuk-do      NaN
# 90            91  female      1974.0   Korea  Gyeongsangbuk-do      NaN
# 104          105  female      1965.0   Korea  Gyeongsangbuk-do      NaN
# 105          106  female      1991.0   Korea  Gyeongsangbuk-do      NaN
# 113          114    male      1946.0   Korea             Daegu      1.0
# 125          126    male      1980.0   Korea           Gwangju      NaN
# 163          164    male      1989.0   Korea           Gwangju      NaN
# 187          188    male      1961.0   Korea      capital area      NaN
# 206          207  female         NaN   Korea  Gyeongsangbuk-do      NaN
# 209          210    male      1985.0   Korea           Gwangju      NaN
# 233          234  female      1974.0   Korea  Gyeongsangbuk-do      NaN
# 236          237  female      2000.0   Korea  Gyeongsangbuk-do      NaN
# 238          239    male      1985.0   Korea           Gwangju      NaN
# 239          240  female      1978.0   Korea  Gyeongsangbuk-do      NaN
# 241          242  female      1965.0   Korea  Gyeongsangbuk-do      NaN
# ...          ...     ...         ...     ...               ...      ...
# 924          925  female      1951.0   Korea  Gyeongsangbuk-do      1.0
# 1183        1184    male      1956.0   Korea      capital area      NaN
# 1188        1189  female      1962.0   Korea  Gyeongsangbuk-do      NaN
# 1189        1190  female      1960.0   Korea  Gyeongsangbuk-do      NaN
# 1195        1196  female      1954.0   Korea  Gyeongsangbuk-do      NaN
# 1246        1247    male      1993.0   Korea      capital area      NaN
# 1737        1738  female      1985.0   Korea  Gyeongsangbuk-do      NaN
# 1795        1796    male      1993.0   Korea  Gyeongsangbuk-do      NaN
# 2947        2948    male      1964.0   Korea  Gyeongsangbuk-do      NaN
# 3046        3047    male      1999.0   Korea      Jeollanam-do      NaN
# 16            33  female      1980.0   Korea             Daegu      NaN
# 17            47  female      1957.0   Korea             Daegu      NaN
# 18            48  female      1948.0   Korea             Daegu      NaN
# 19            49    male      1962.0   Korea             Daegu      NaN
# 20            50    male      1944.0   Korea             Daegu      NaN
# 21            51  female      1959.0   Korea             Daegu      NaN
# 27           140  female      1988.0   Korea             Daegu      NaN
# 28           162    male      1987.0   Korea             Daegu      NaN
# 29           164    male      1989.0   Korea           Gwangju      NaN
# 35           441  female      1959.0   Korea      capital area      NaN
# 37           489    male      1985.0   Korea           Gwangju      NaN
# 38           565    male      1980.0   Korea      capital area      NaN
# 40           589  female      1985.0   Korea           Gwangju      NaN
# 41           611    male      1985.0   Korea           Gwangju      NaN
# 46           835    male      1986.0   Korea      capital area      NaN
# 50          1227    male      1981.0   Korea      capital area      NaN
# 55          1256  female      1987.0   Korea           Daejeon      NaN
# 66          2468  female      1985.0   Korea      capital area      NaN
# 41           611    male      1985.0   Korea           Gwangju      NaN
# 50          1227    male      1981.0   Korea      capital area      NaN
#
#                    group      infection_reason  infection_order  infected_by  \
# 30    Shincheonji Church                   NaN              NaN          NaN
# 33    Shincheonji Church                   NaN              NaN          NaN
# 34    Shincheonji Church                   NaN              NaN          NaN
# 35    Shincheonji Church                   NaN              NaN          NaN
# 38    Shincheonji Church                   NaN              NaN          NaN
# 40    Shincheonji Church                   NaN              NaN          NaN
# 41    Shincheonji Church                   NaN              NaN          NaN
# 42    Shincheonji Church                   NaN              NaN          NaN
# 43    Shincheonji Church                   NaN              NaN          NaN
# 46    Shincheonji Church  contact with patient              NaN         31.0
# 47    Shincheonji Church  contact with patient              NaN         31.0
# 48    Shincheonji Church  contact with patient              NaN         31.0
# 49    Shincheonji Church  contact with patient              NaN         31.0
# 50    Shincheonji Church  contact with patient              NaN         31.0
# 65    Shincheonji Church        visit to Daegu              NaN          NaN
# 84    Shincheonji Church                   NaN              NaN          NaN
# 90    Shincheonji Church        visit to Daegu              NaN          NaN
# 104   Shincheonji Church        visit to Daegu              NaN          NaN
# 105   Shincheonji Church        visit to Daegu              NaN          NaN
# 113   Shincheonji Church                   NaN              NaN          NaN
# 125   Shincheonji Church        visit to Daegu              NaN          NaN
# 163   Shincheonji Church  contact with patient              NaN        126.0
# 187   Shincheonji Church        visit to Daegu              NaN          NaN
# 206   Shincheonji Church        visit to Daegu              NaN          NaN
# 209   Shincheonji Church        visit to Daegu              NaN          NaN
# 233   Shincheonji Church        visit to Daegu              NaN          NaN
# 236   Shincheonji Church        visit to Daegu              NaN          NaN
# 238   Shincheonji Church        visit to Daegu              NaN          NaN
# 239   Shincheonji Church        visit to Daegu              NaN          NaN
# 241   Shincheonji Church        visit to Daegu              NaN          NaN
# ...                  ...                   ...              ...          ...
# 924   Shincheonji Church  contact with patient              NaN          NaN
# 1183  Shincheonji Church                   NaN              NaN          NaN
# 1188  Shincheonji Church                   NaN              NaN          NaN
# 1189  Shincheonji Church                   NaN              NaN          NaN
# 1195  Shincheonji Church                   NaN              NaN          NaN
# 1246  Shincheonji Church        visit to Daegu              NaN          NaN
# 1737  Shincheonji Church        visit to Daegu              NaN          NaN
# 1795  Shincheonji Church                   NaN              NaN          NaN
# 2947  Shincheonji Church  contact with patient              NaN          NaN
# 3046  Shincheonji Church                   NaN              NaN          NaN
# 16                   NaN  contact with patient              NaN         31.0
# 17    Shincheonji Church  contact with patient              NaN         31.0
# 18    Shincheonji Church  contact with patient              NaN         31.0
# 19    Shincheonji Church  contact with patient              NaN         31.0
# 20    Shincheonji Church  contact with patient              NaN         31.0
# 21    Shincheonji Church  contact with patient              NaN         31.0
# 27                   NaN  contact with patient              NaN         31.0
# 28                   NaN  contact with patient              NaN         31.0
# 29    Shincheonji Church  contact with patient              NaN        126.0
# 35                   NaN  contact with patient              NaN        246.0
# 37                   NaN  contact with patient              NaN        126.0
# 38                   NaN  contact with patient              NaN        246.0
# 40                   NaN  contact with patient              NaN        126.0
# 41                   NaN  contact with patient              NaN        164.0
# 46    Shincheonji Church  contact with patient              NaN        188.0
# 50                   NaN  contact with patient              NaN        835.0
# 55                   NaN                   NaN              NaN         44.0
# 66                   NaN  contact with patient              NaN       1247.0
# 41                   NaN  contact with patient              NaN        164.0
# 50                   NaN  contact with patient              NaN        835.0
#
#       contact_number confirmed_date released_date deceased_date     state
# 30            1160.0     2020-02-18           NaN           NaN  isolated
# 33               NaN     2020-02-18           NaN           NaN  isolated
# 34               NaN     2020-02-18           NaN           NaN  isolated
# 35               NaN     2020-02-18           NaN           NaN  isolated
# 38              31.0     2020-02-18    2020-03-03           NaN  released
# 40               NaN     2020-02-19           NaN           NaN  isolated
# 41               NaN     2020-02-19           NaN           NaN  isolated
# 42               NaN     2020-02-19           NaN           NaN  isolated
# 43               NaN     2020-02-19           NaN           NaN  isolated
# 46               NaN     2020-02-19           NaN           NaN  isolated
# 47               NaN     2020-02-19           NaN           NaN  isolated
# 48               NaN     2020-02-19           NaN           NaN  isolated
# 49               NaN     2020-02-19    2020-03-02           NaN  released
# 50               NaN     2020-02-19    2020-02-26           NaN  released
# 65               NaN     2020-02-19           NaN           NaN  isolated
# 84               NaN     2020-02-20           NaN           NaN  isolated
# 90               NaN     2020-02-20           NaN           NaN  isolated
# 104              NaN     2020-02-21           NaN           NaN  isolated
# 105              NaN     2020-02-21           NaN           NaN  isolated
# 113              NaN     2020-02-21           NaN    2020-02-26  deceased
# 125             65.0     2020-02-21           NaN           NaN  isolated
# 163              NaN     2020-02-21           NaN           NaN  isolated
# 187              NaN     2020-02-21           NaN           NaN  isolated
# 206              NaN     2020-02-22           NaN           NaN  isolated
# 209             30.0     2020-02-22           NaN           NaN  isolated
# 233              NaN     2020-02-22           NaN           NaN  isolated
# 236              NaN     2020-02-22           NaN           NaN  isolated
# 238             14.0     2020-02-22           NaN           NaN  isolated
# 239              NaN     2020-02-22           NaN           NaN  isolated
# 241              NaN     2020-02-22           NaN           NaN  isolated
# ...              ...            ...           ...           ...       ...
# 924              NaN     2020-02-25           NaN    2020-02-24  deceased
# 1183             NaN     2020-02-26           NaN           NaN  isolated
# 1188             NaN     2020-02-26           NaN           NaN  isolated
# 1189             NaN     2020-02-26           NaN           NaN  isolated
# 1195             NaN     2020-02-26           NaN           NaN  isolated
# 1246             NaN     2020-02-26           NaN           NaN  isolated
# 1737             NaN     2020-02-26           NaN           NaN  isolated
# 1795             NaN     2020-02-27           NaN           NaN  isolated
# 2947             NaN     2020-02-29           NaN           NaN  isolated
# 3046            23.0     2020-02-29           NaN           NaN  isolated
# 16               NaN     2020-02-18           NaN           NaN  isolated
# 17               NaN     2020-02-19           NaN           NaN  isolated
# 18               NaN     2020-02-19           NaN           NaN  isolated
# 19               NaN     2020-02-19           NaN           NaN  isolated
# 20               NaN     2020-02-19    2020-03-02           NaN  released
# 21               NaN     2020-02-19    2020-02-26           NaN  released
# 27               NaN     2020-02-21           NaN           NaN  isolated
# 28               NaN     2020-02-21           NaN           NaN  isolated
# 29               NaN     2020-02-21           NaN           NaN  isolated
# 35               NaN     2020-02-23           NaN           NaN  isolated
# 37              39.0     2020-02-23           NaN           NaN  isolated
# 38               NaN     2020-02-23           NaN           NaN  isolated
# 40              47.0     2020-02-23    2020-02-27           NaN  released
# 41               NaN     2020-02-24           NaN           NaN  isolated
# 46               NaN     2020-02-25           NaN           NaN  isolated
# 50               NaN     2020-02-26           NaN           NaN  isolated
# 55               NaN     2020-02-26    2020-03-02           NaN  released
# 66               NaN     2020-02-29    2020-03-04           NaN  released
# 41               NaN     2020-02-24           NaN           NaN  isolated
# 50               NaN     2020-02-26           NaN           NaN  isolated
#
# [78 rows x 15 columns]

# %%
df_patient['group'].value_counts()
# Out:
# Shincheonji Church               58
# Eunpyeong St. Mary's Hospital    13
# Cheongdo Daenam Hospital          9
# Pilgrimage                        6
# Name: group, dtype: int64

# %%
df_patient['region'].value_counts()
# Out:
# capital area           191
# Gyeongsangbuk-do       140
# Daegu                   57
# Daejeon                 13
# Gwangju                 11
# Gangwon-do               5
# Jeju-do                  4
# filtered at airport      4
# Jeollabuk-do             3
# Jeollanam-do             3
# Ulsan                    2
# Chungcheongbuk-do        2
# Chungcheongnam-do        1
# Busan                    1
# Name: region, dtype: int64
